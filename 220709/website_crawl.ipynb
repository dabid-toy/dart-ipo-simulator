# %%
import os
import requests
import pandas as pd
from datetime import datetime
from bs4 import BeautifulSoup
from collections import OrderedDict
import time

import re


def get_ipo_data(url):
    info = OrderedDict()

    html = requests.get(url).text
    soup = BeautifulSoup(html, 'html.parser')
    tables = soup('table')

    #### 공모정보 테이블에서 데이터 가져오기 ####
    info_table = list(filter(lambda x: x.attrs.get(
        'summary') == '공모정보', tables))[0]  # 공모정보
    info_tds = info_table.select('td')
    info_texts = [i.text for i in info_tds]

    # 0~9가 아닌 것을 ''으로 교체, 총 공모주식수
    info['ipo_total'] = re.sub('[^0-9]', '', info_texts[1])
    info['face_value'] = re.sub('[^0-9]', '', info_texts[3])  # 액면가

    ## 신주,구주발행
    ipo_rates = re.findall('\((.*?)\)', info_texts[5])
    if len(ipo_rates) == 1:
        info['new_rate'] = ipo_rates[0]
        info['old_rate'] = None
    else:
        info['new_rate'] = ipo_rates[0]
        info['old_rate'] = ipo_rates[1]

    info['ipo_type'] = info_texts[5]  # 공모타입
    info['wish_price_min'] = re.sub(
        '[^0-9]', '', info_texts[7].split(" ~ ")[0])  # 희망공모가(최저)
    info['wish_price_max'] = re.sub(
        '[^0-9]', '', info_texts[7].split(" ~ ")[1])  # 희망공모가(최고)
    info['sub_rate'] = info_texts[9]  # 청약경쟁률
    info['final_price'] = re.sub('[^0-9]', '', info_texts[11])
    info['host_party'] = info_texts[15]

    #### 청약일정의 공모사항 테이블에서 데이터 가져오기 ####
    # x is bs element

    details_table = list(filter(lambda x: x.attrs.get('summary') == '공모청약일정', tables))[
        0].select_one('table')  # 공모정보
    # details_table = list(filter(lambda x: "청약증거금율" in x.text, tables))[1]  ## 공모사항
    details_trs = details_table.select('tr')
    info['employee_rate'] = details_trs[5].select('td')[2].text  # 비중
    info['employee_margin'] = details_trs[5].select(
        'td')[3].text.replace("청약증거금율 : ", "")

    info['org_rate'] = details_trs[6].select('td')[1].text
    info['normal_rate'] = details_trs[7].select('td')[1].text
    info['normal_margin'] = details_trs[7].select(
        'td')[2].text.replace("청약증거금율 : ", "")

    def clean_dict(input_dict):  # my_dict is a list of dict
        ini_list = [
            '15일 확약',
            '1개월 확약',
            '3개월 확약',
            '6개월 확약',
            '총 수량 대비 비율(%)',
        ]
        template_dict = OrderedDict(zip(ini_list, [None]*len(ini_list)))

        for key, value in input_dict.items():
            template_dict[key] = value
        return template_dict
    ############# 의무보율확약비율 ##############
    try:
        mand_table = list(
            filter(lambda x: "총 수량 대비 비율(%)" in x.text, tables))[-1]  # 공모사항
        mand_table_trs = mand_table.select('tr')
        ## "15일 확약"
        ## "1개월 확약"
        ## "3개월 확약"
        ## "6개월 확약"
        # "합계"
        ## "15일 확약"

        # 어차피 0은 header, -2은 합계, -1은 총 수량 대비 비율



        tmp_dict = OrderedDict()
        for i, d in enumerate(mand_table_trs[1:]):
            tmp_dict[d.select('td')[0].text] = d.select('td')[1].text
        tmp_dict = clean_dict(tmp_dict)

        info.update(tmp_dict)
    except:
        tmp_dict = OrderedDict()
        tmp_dict = clean_dict(tmp_dict)
        info.update(tmp_dict)

    ############ 수요예측 참여내역
    try:
        demand_part_table = list(
            filter(lambda x: "단순경쟁" in x.text, tables))[-1]  # 수요예측
        info['demand_count'] = demand_part_table.select(
            'tr')[1].select('td')[0].text
        info['demand_ratio'] =  demand_part_table.select(
            'tr')[1].select('td')[2].text.replace(":1","")
    except:
        info['demand_count'] = None
        info['demand_ratio'] = None

    return info



def getIPOElements(page_no):
    url = 'https://www.38.co.kr/html/fund/index.htm?o=nw&page={}'.format(page_no)
    # url로부터 신규상장종목 리스트가 들어있는 table 태그를 가져온다. (38커뮤니케이션)
    # summary 속성이 '신규상장종목'인 태그 솔팅

    html = requests.get(url.format(page_no)).text
    soup = BeautifulSoup(html, 'html.parser')
    tables = soup('table')
    table_ipo_list = list(filter(lambda x: x.attrs.get('summary') == '신규상장종목', tables))[0]

    # 테이블 헤더 태그(thead)를 읽는다.
    head = table_ipo_list('thead')[0]
    th = head('tr')[0]('th')
    column_headers = [x.text for x in th]

    # 테이블 본체 (tbody)를 읽어서 리스트에 딕셔너리 형태로 저장
    result = []
    tbody = table_ipo_list('tbody')[0]
    rows = tbody('tr')
    for row in rows:
        td = row('td')
        info = OrderedDict()
        for i, e in enumerate(td):
            header_text = column_headers[i]

            if len(header_text) == 0:
                continue
            temp = e.text.replace('\xa0', '')
            temp = temp.replace('%', '')

            if header_text in ['공모가(원)', '시초가(원)', '첫날종가(원)', '현재가(원)']:
                if temp in ['-', '예정', '상장']:
                    info[header_text] = '' # NaN
                else:
                    info[header_text] = int(temp.replace(',', ''))
            elif header_text in ['공모가대비등락률(%)', '시초/공모(%)', '전일비(%)']:
                if temp in ['-'] or len(temp) == 0:
                    info[header_text] = ''
                else:
                    info[header_text] = float(temp)
            elif header_text in ['신규상장일']:
                info[header_text] = datetime.strptime(e.text, '%Y/%m/%d')
            elif header_text in ['기업명']:
                info[header_text] = temp.replace('(유가)', '')
                target_no = e.select_one('a')['href'][1:]
                print(f'https://www.38.co.kr/html/fund/{target_no}')
                info['url'] = f'https://www.38.co.kr/html/fund{target_no}'
            else:
                info[header_text] = e.text
        info.update(get_ipo_data(info['url']))
        result.append(info)

    return result

# a = getIPOElements(1)
# for i in a:
#     print(i)

# 해당 연도부터 현재까지 상장한 IPO 종목 pandas DF화(스팩, 리츠 제외)
def getIPOAllList(year: int) -> pd.DataFrame:
    result = list()
    page_no = 1 # 1페이지부터 탐색

    while True:
        time.sleep(0.3)
        page_result = getIPOElements(page_no)
        result.extend(page_result)

        dates = [x.get('신규상장일') for x in page_result]
        find = list(filter(lambda x: x.year < year, dates))
        if len(find) > 0:
            break
        page_no += 1
    # 스팩, 리츠 종목은 제외
    result = list(filter(lambda x: x.get('신규상장일').year >= year and '스팩' not in x.get('기업명') and '리츠' not in x.get('기업명'), result))

    return pd.DataFrame(result)

a = getIPOAllList(2017)
a.to_csv('2017_v3.csv')
# Out:
# https://www.38.co.kr/html/fund//?o=v&no=1799&l=
# https://www.38.co.kr/html/fund//?o=v&no=1797&l=
# https://www.38.co.kr/html/fund//?o=v&no=1792&l=
# https://www.38.co.kr/html/fund//?o=v&no=1795&l=
# https://www.38.co.kr/html/fund//?o=v&no=1794&l=
# https://www.38.co.kr/html/fund//?o=v&no=1791&l=
# https://www.38.co.kr/html/fund//?o=v&no=1793&l=
# https://www.38.co.kr/html/fund//?o=v&no=1788&l=
# https://www.38.co.kr/html/fund//?o=v&no=1790&l=
# https://www.38.co.kr/html/fund//?o=v&no=1789&l=
# https://www.38.co.kr/html/fund//?o=v&no=1787&l=
# https://www.38.co.kr/html/fund//?o=v&no=1783&l=
# https://www.38.co.kr/html/fund//?o=v&no=1784&l=
# https://www.38.co.kr/html/fund//?o=v&no=1786&l=
# https://www.38.co.kr/html/fund//?o=v&no=1785&l=
# https://www.38.co.kr/html/fund//?o=v&no=1780&l=
# https://www.38.co.kr/html/fund//?o=v&no=1779&l=
# https://www.38.co.kr/html/fund//?o=v&no=1782&l=
# https://www.38.co.kr/html/fund//?o=v&no=1781&l=
# https://www.38.co.kr/html/fund//?o=v&no=1778&l=
# https://www.38.co.kr/html/fund//?o=v&no=1777&l=
# https://www.38.co.kr/html/fund//?o=v&no=1775&l=
# https://www.38.co.kr/html/fund//?o=v&no=1774&l=
# https://www.38.co.kr/html/fund//?o=v&no=1771&l=
# https://www.38.co.kr/html/fund//?o=v&no=1770&l=
# https://www.38.co.kr/html/fund//?o=v&no=1769&l=
# https://www.38.co.kr/html/fund//?o=v&no=1766&l=
# https://www.38.co.kr/html/fund//?o=v&no=1765&l=
# https://www.38.co.kr/html/fund//?o=v&no=1768&l=
# https://www.38.co.kr/html/fund//?o=v&no=1759&l=
# https://www.38.co.kr/html/fund//?o=v&no=1767&l=
# https://www.38.co.kr/html/fund//?o=v&no=1762&l=
# https://www.38.co.kr/html/fund//?o=v&no=1764&l=
# https://www.38.co.kr/html/fund//?o=v&no=1763&l=
# https://www.38.co.kr/html/fund//?o=v&no=1761&l=
# https://www.38.co.kr/html/fund//?o=v&no=1758&l=
# https://www.38.co.kr/html/fund//?o=v&no=1755&l=
# https://www.38.co.kr/html/fund//?o=v&no=1754&l=
# https://www.38.co.kr/html/fund//?o=v&no=1756&l=
# https://www.38.co.kr/html/fund//?o=v&no=1752&l=
# https://www.38.co.kr/html/fund//?o=v&no=1750&l=
# https://www.38.co.kr/html/fund//?o=v&no=1753&l=
# https://www.38.co.kr/html/fund//?o=v&no=1748&l=
# https://www.38.co.kr/html/fund//?o=v&no=1749&l=
# https://www.38.co.kr/html/fund//?o=v&no=1746&l=
# https://www.38.co.kr/html/fund//?o=v&no=1747&l=
# https://www.38.co.kr/html/fund//?o=v&no=1744&l=
# https://www.38.co.kr/html/fund//?o=v&no=1751&l=
# https://www.38.co.kr/html/fund//?o=v&no=1741&l=
# https://www.38.co.kr/html/fund//?o=v&no=1745&l=
# https://www.38.co.kr/html/fund//?o=v&no=1742&l=
# https://www.38.co.kr/html/fund//?o=v&no=1743&l=
# https://www.38.co.kr/html/fund//?o=v&no=1737&l=
# https://www.38.co.kr/html/fund//?o=v&no=1736&l=
# https://www.38.co.kr/html/fund//?o=v&no=1739&l=
# https://www.38.co.kr/html/fund//?o=v&no=1732&l=
# https://www.38.co.kr/html/fund//?o=v&no=1740&l=
# https://www.38.co.kr/html/fund//?o=v&no=1733&l=
# https://www.38.co.kr/html/fund//?o=v&no=1734&l=
# https://www.38.co.kr/html/fund//?o=v&no=1735&l=
# https://www.38.co.kr/html/fund//?o=v&no=1729&l=
# https://www.38.co.kr/html/fund//?o=v&no=1731&l=
# https://www.38.co.kr/html/fund//?o=v&no=1726&l=
# https://www.38.co.kr/html/fund//?o=v&no=1728&l=
# https://www.38.co.kr/html/fund//?o=v&no=1730&l=
# https://www.38.co.kr/html/fund//?o=v&no=1727&l=
# https://www.38.co.kr/html/fund//?o=v&no=1725&l=
# https://www.38.co.kr/html/fund//?o=v&no=1724&l=
# https://www.38.co.kr/html/fund//?o=v&no=1722&l=
# https://www.38.co.kr/html/fund//?o=v&no=1721&l=
# https://www.38.co.kr/html/fund//?o=v&no=1723&l=
# https://www.38.co.kr/html/fund//?o=v&no=1720&l=
# https://www.38.co.kr/html/fund//?o=v&no=1711&l=
# https://www.38.co.kr/html/fund//?o=v&no=1718&l=
# https://www.38.co.kr/html/fund//?o=v&no=1709&l=
# https://www.38.co.kr/html/fund//?o=v&no=1717&l=
# https://www.38.co.kr/html/fund//?o=v&no=1716&l=
# https://www.38.co.kr/html/fund//?o=v&no=1682&l=
# https://www.38.co.kr/html/fund//?o=v&no=1715&l=
# https://www.38.co.kr/html/fund//?o=v&no=1714&l=
# https://www.38.co.kr/html/fund//?o=v&no=1705&l=
# https://www.38.co.kr/html/fund//?o=v&no=1713&l=
# https://www.38.co.kr/html/fund//?o=v&no=1712&l=
# https://www.38.co.kr/html/fund//?o=v&no=1695&l=
# https://www.38.co.kr/html/fund//?o=v&no=1710&l=
# https://www.38.co.kr/html/fund//?o=v&no=1697&l=
# https://www.38.co.kr/html/fund//?o=v&no=1707&l=
# https://www.38.co.kr/html/fund//?o=v&no=1706&l=
# https://www.38.co.kr/html/fund//?o=v&no=1702&l=
# https://www.38.co.kr/html/fund//?o=v&no=1703&l=
# https://www.38.co.kr/html/fund//?o=v&no=1704&l=
# https://www.38.co.kr/html/fund//?o=v&no=1692&l=
# https://www.38.co.kr/html/fund//?o=v&no=1687&l=
# https://www.38.co.kr/html/fund//?o=v&no=1700&l=
# https://www.38.co.kr/html/fund//?o=v&no=1701&l=
# https://www.38.co.kr/html/fund//?o=v&no=1694&l=
# https://www.38.co.kr/html/fund//?o=v&no=1699&l=
# https://www.38.co.kr/html/fund//?o=v&no=1693&l=
# https://www.38.co.kr/html/fund//?o=v&no=1696&l=
# https://www.38.co.kr/html/fund//?o=v&no=1698&l=
# https://www.38.co.kr/html/fund//?o=v&no=1690&l=
# https://www.38.co.kr/html/fund//?o=v&no=1691&l=
# https://www.38.co.kr/html/fund//?o=v&no=1686&l=
# https://www.38.co.kr/html/fund//?o=v&no=1689&l=
# https://www.38.co.kr/html/fund//?o=v&no=1684&l=
# https://www.38.co.kr/html/fund//?o=v&no=1688&l=
# https://www.38.co.kr/html/fund//?o=v&no=1677&l=
# https://www.38.co.kr/html/fund//?o=v&no=1683&l=
# https://www.38.co.kr/html/fund//?o=v&no=1672&l=
# https://www.38.co.kr/html/fund//?o=v&no=1685&l=
# https://www.38.co.kr/html/fund//?o=v&no=1674&l=
# https://www.38.co.kr/html/fund//?o=v&no=1681&l=
# https://www.38.co.kr/html/fund//?o=v&no=1680&l=
# https://www.38.co.kr/html/fund//?o=v&no=1673&l=
# https://www.38.co.kr/html/fund//?o=v&no=1675&l=
# https://www.38.co.kr/html/fund//?o=v&no=1671&l=
# https://www.38.co.kr/html/fund//?o=v&no=1678&l=
# https://www.38.co.kr/html/fund//?o=v&no=1676&l=
# https://www.38.co.kr/html/fund//?o=v&no=1679&l=
# https://www.38.co.kr/html/fund//?o=v&no=1669&l=
# https://www.38.co.kr/html/fund//?o=v&no=1668&l=
# https://www.38.co.kr/html/fund//?o=v&no=1670&l=
# https://www.38.co.kr/html/fund//?o=v&no=1667&l=
# https://www.38.co.kr/html/fund//?o=v&no=1665&l=
# https://www.38.co.kr/html/fund//?o=v&no=1647&l=
# https://www.38.co.kr/html/fund//?o=v&no=1663&l=
# https://www.38.co.kr/html/fund//?o=v&no=1664&l=
# https://www.38.co.kr/html/fund//?o=v&no=1666&l=
# https://www.38.co.kr/html/fund//?o=v&no=1662&l=
# https://www.38.co.kr/html/fund//?o=v&no=1661&l=
# https://www.38.co.kr/html/fund//?o=v&no=1654&l=
# https://www.38.co.kr/html/fund//?o=v&no=1659&l=
# https://www.38.co.kr/html/fund//?o=v&no=1651&l=
# https://www.38.co.kr/html/fund//?o=v&no=1658&l=
# https://www.38.co.kr/html/fund//?o=v&no=1660&l=
# https://www.38.co.kr/html/fund//?o=v&no=1657&l=
# https://www.38.co.kr/html/fund//?o=v&no=1655&l=
# https://www.38.co.kr/html/fund//?o=v&no=1648&l=
# https://www.38.co.kr/html/fund//?o=v&no=1653&l=
# https://www.38.co.kr/html/fund//?o=v&no=1652&l=
# https://www.38.co.kr/html/fund//?o=v&no=1650&l=
# https://www.38.co.kr/html/fund//?o=v&no=1644&l=
# https://www.38.co.kr/html/fund//?o=v&no=1649&l=
# https://www.38.co.kr/html/fund//?o=v&no=1646&l=
# https://www.38.co.kr/html/fund//?o=v&no=1639&l=
# https://www.38.co.kr/html/fund//?o=v&no=1643&l=
# https://www.38.co.kr/html/fund//?o=v&no=1633&l=
# https://www.38.co.kr/html/fund//?o=v&no=1642&l=
# https://www.38.co.kr/html/fund//?o=v&no=1634&l=
# https://www.38.co.kr/html/fund//?o=v&no=1641&l=
# https://www.38.co.kr/html/fund//?o=v&no=1635&l=
# https://www.38.co.kr/html/fund//?o=v&no=1629&l=
# https://www.38.co.kr/html/fund//?o=v&no=1640&l=
# https://www.38.co.kr/html/fund//?o=v&no=1637&l=
# https://www.38.co.kr/html/fund//?o=v&no=1638&l=
# https://www.38.co.kr/html/fund//?o=v&no=1628&l=
# https://www.38.co.kr/html/fund//?o=v&no=1636&l=
# https://www.38.co.kr/html/fund//?o=v&no=1621&l=
# https://www.38.co.kr/html/fund//?o=v&no=1631&l=
# https://www.38.co.kr/html/fund//?o=v&no=1625&l=
# https://www.38.co.kr/html/fund//?o=v&no=1622&l=
# https://www.38.co.kr/html/fund//?o=v&no=1632&l=
# https://www.38.co.kr/html/fund//?o=v&no=1630&l=
# https://www.38.co.kr/html/fund//?o=v&no=1627&l=
# https://www.38.co.kr/html/fund//?o=v&no=1605&l=
# https://www.38.co.kr/html/fund//?o=v&no=1624&l=
# https://www.38.co.kr/html/fund//?o=v&no=1623&l=
# https://www.38.co.kr/html/fund//?o=v&no=1610&l=
# https://www.38.co.kr/html/fund//?o=v&no=1615&l=
# https://www.38.co.kr/html/fund//?o=v&no=1620&l=
# https://www.38.co.kr/html/fund//?o=v&no=1619&l=
# https://www.38.co.kr/html/fund//?o=v&no=1618&l=
# https://www.38.co.kr/html/fund//?o=v&no=1617&l=
# https://www.38.co.kr/html/fund//?o=v&no=1614&l=
# https://www.38.co.kr/html/fund//?o=v&no=1596&l=
# https://www.38.co.kr/html/fund//?o=v&no=1616&l=
# https://www.38.co.kr/html/fund//?o=v&no=1611&l=
# https://www.38.co.kr/html/fund//?o=v&no=1600&l=
# https://www.38.co.kr/html/fund//?o=v&no=1609&l=
# https://www.38.co.kr/html/fund//?o=v&no=1612&l=
# https://www.38.co.kr/html/fund//?o=v&no=1613&l=
# https://www.38.co.kr/html/fund//?o=v&no=1607&l=
# https://www.38.co.kr/html/fund//?o=v&no=1591&l=
# https://www.38.co.kr/html/fund//?o=v&no=1606&l=
# https://www.38.co.kr/html/fund//?o=v&no=1608&l=
# https://www.38.co.kr/html/fund//?o=v&no=1602&l=
# https://www.38.co.kr/html/fund//?o=v&no=1604&l=
# https://www.38.co.kr/html/fund//?o=v&no=1597&l=
# https://www.38.co.kr/html/fund//?o=v&no=1598&l=
# https://www.38.co.kr/html/fund//?o=v&no=1588&l=
# https://www.38.co.kr/html/fund//?o=v&no=1599&l=
# https://www.38.co.kr/html/fund//?o=v&no=1589&l=
# https://www.38.co.kr/html/fund//?o=v&no=1585&l=
# https://www.38.co.kr/html/fund//?o=v&no=1583&l=
# https://www.38.co.kr/html/fund//?o=v&no=1594&l=
# https://www.38.co.kr/html/fund//?o=v&no=1595&l=
# https://www.38.co.kr/html/fund//?o=v&no=1593&l=
# https://www.38.co.kr/html/fund//?o=v&no=1592&l=
# https://www.38.co.kr/html/fund//?o=v&no=1581&l=
# https://www.38.co.kr/html/fund//?o=v&no=1590&l=
# https://www.38.co.kr/html/fund//?o=v&no=1580&l=
# https://www.38.co.kr/html/fund//?o=v&no=1587&l=
# https://www.38.co.kr/html/fund//?o=v&no=1584&l=
# https://www.38.co.kr/html/fund//?o=v&no=1582&l=
# https://www.38.co.kr/html/fund//?o=v&no=1579&l=
# https://www.38.co.kr/html/fund//?o=v&no=1573&l=
# https://www.38.co.kr/html/fund//?o=v&no=1571&l=
# https://www.38.co.kr/html/fund//?o=v&no=1561&l=
# https://www.38.co.kr/html/fund//?o=v&no=1564&l=
# https://www.38.co.kr/html/fund//?o=v&no=1578&l=
# https://www.38.co.kr/html/fund//?o=v&no=1576&l=
# https://www.38.co.kr/html/fund//?o=v&no=1570&l=
# https://www.38.co.kr/html/fund//?o=v&no=1569&l=
# https://www.38.co.kr/html/fund//?o=v&no=1574&l=
# https://www.38.co.kr/html/fund//?o=v&no=1565&l=
# https://www.38.co.kr/html/fund//?o=v&no=1567&l=
# https://www.38.co.kr/html/fund//?o=v&no=1559&l=
# https://www.38.co.kr/html/fund//?o=v&no=1568&l=
# https://www.38.co.kr/html/fund//?o=v&no=1566&l=
# https://www.38.co.kr/html/fund//?o=v&no=1556&l=
# https://www.38.co.kr/html/fund//?o=v&no=1560&l=
# https://www.38.co.kr/html/fund//?o=v&no=1554&l=
# https://www.38.co.kr/html/fund//?o=v&no=1553&l=
# https://www.38.co.kr/html/fund//?o=v&no=1558&l=
# https://www.38.co.kr/html/fund//?o=v&no=1555&l=
# https://www.38.co.kr/html/fund//?o=v&no=1544&l=
# https://www.38.co.kr/html/fund//?o=v&no=1552&l=
# https://www.38.co.kr/html/fund//?o=v&no=1551&l=
# https://www.38.co.kr/html/fund//?o=v&no=1549&l=
# https://www.38.co.kr/html/fund//?o=v&no=1547&l=
# https://www.38.co.kr/html/fund//?o=v&no=1550&l=
# https://www.38.co.kr/html/fund//?o=v&no=1546&l=
# https://www.38.co.kr/html/fund//?o=v&no=1545&l=
# https://www.38.co.kr/html/fund//?o=v&no=1548&l=
# https://www.38.co.kr/html/fund//?o=v&no=1542&l=
# https://www.38.co.kr/html/fund//?o=v&no=1541&l=
# https://www.38.co.kr/html/fund//?o=v&no=1538&l=
# https://www.38.co.kr/html/fund//?o=v&no=1540&l=
# https://www.38.co.kr/html/fund//?o=v&no=1536&l=
# https://www.38.co.kr/html/fund//?o=v&no=1543&l=
# https://www.38.co.kr/html/fund//?o=v&no=1533&l=
# https://www.38.co.kr/html/fund//?o=v&no=1537&l=
# https://www.38.co.kr/html/fund//?o=v&no=1539&l=
# https://www.38.co.kr/html/fund//?o=v&no=1534&l=
# https://www.38.co.kr/html/fund//?o=v&no=1535&l=
# https://www.38.co.kr/html/fund//?o=v&no=1527&l=
# https://www.38.co.kr/html/fund//?o=v&no=1520&l=
# https://www.38.co.kr/html/fund//?o=v&no=1532&l=
# https://www.38.co.kr/html/fund//?o=v&no=1530&l=
# https://www.38.co.kr/html/fund//?o=v&no=1526&l=
# https://www.38.co.kr/html/fund//?o=v&no=1528&l=
# https://www.38.co.kr/html/fund//?o=v&no=1531&l=
# https://www.38.co.kr/html/fund//?o=v&no=1525&l=
# https://www.38.co.kr/html/fund//?o=v&no=1524&l=
# https://www.38.co.kr/html/fund//?o=v&no=1522&l=
# https://www.38.co.kr/html/fund//?o=v&no=1523&l=
# https://www.38.co.kr/html/fund//?o=v&no=1521&l=
# https://www.38.co.kr/html/fund//?o=v&no=1519&l=
# https://www.38.co.kr/html/fund//?o=v&no=1513&l=
# https://www.38.co.kr/html/fund//?o=v&no=1509&l=
# https://www.38.co.kr/html/fund//?o=v&no=1508&l=
# https://www.38.co.kr/html/fund//?o=v&no=1510&l=
# https://www.38.co.kr/html/fund//?o=v&no=1507&l=
# https://www.38.co.kr/html/fund//?o=v&no=1503&l=
# https://www.38.co.kr/html/fund//?o=v&no=1506&l=
# https://www.38.co.kr/html/fund//?o=v&no=1505&l=
# https://www.38.co.kr/html/fund//?o=v&no=1502&l=
# https://www.38.co.kr/html/fund//?o=v&no=1501&l=
# https://www.38.co.kr/html/fund//?o=v&no=1498&l=
# https://www.38.co.kr/html/fund//?o=v&no=1499&l=
# https://www.38.co.kr/html/fund//?o=v&no=1500&l=
# https://www.38.co.kr/html/fund//?o=v&no=1494&l=
# https://www.38.co.kr/html/fund//?o=v&no=1478&l=
# https://www.38.co.kr/html/fund//?o=v&no=1497&l=
# https://www.38.co.kr/html/fund//?o=v&no=1493&l=
# https://www.38.co.kr/html/fund//?o=v&no=1495&l=
# https://www.38.co.kr/html/fund//?o=v&no=1496&l=
# https://www.38.co.kr/html/fund//?o=v&no=1484&l=
# https://www.38.co.kr/html/fund//?o=v&no=1488&l=
# https://www.38.co.kr/html/fund//?o=v&no=1491&l=
# https://www.38.co.kr/html/fund//?o=v&no=1492&l=
# https://www.38.co.kr/html/fund//?o=v&no=1489&l=
# https://www.38.co.kr/html/fund//?o=v&no=1486&l=
# https://www.38.co.kr/html/fund//?o=v&no=1481&l=
# https://www.38.co.kr/html/fund//?o=v&no=1483&l=
# https://www.38.co.kr/html/fund//?o=v&no=1485&l=
# https://www.38.co.kr/html/fund//?o=v&no=1482&l=
# https://www.38.co.kr/html/fund//?o=v&no=1490&l=
# https://www.38.co.kr/html/fund//?o=v&no=1480&l=
# https://www.38.co.kr/html/fund//?o=v&no=1468&l=
# https://www.38.co.kr/html/fund//?o=v&no=1479&l=
# https://www.38.co.kr/html/fund//?o=v&no=1476&l=
# https://www.38.co.kr/html/fund//?o=v&no=1477&l=
# https://www.38.co.kr/html/fund//?o=v&no=1470&l=
# https://www.38.co.kr/html/fund//?o=v&no=1474&l=
# https://www.38.co.kr/html/fund//?o=v&no=1472&l=
# https://www.38.co.kr/html/fund//?o=v&no=1475&l=
# https://www.38.co.kr/html/fund//?o=v&no=1473&l=
# https://www.38.co.kr/html/fund//?o=v&no=1469&l=
# https://www.38.co.kr/html/fund//?o=v&no=1466&l=
# https://www.38.co.kr/html/fund//?o=v&no=1471&l=
# https://www.38.co.kr/html/fund//?o=v&no=1467&l=
# https://www.38.co.kr/html/fund//?o=v&no=1465&l=
# https://www.38.co.kr/html/fund//?o=v&no=1463&l=
# https://www.38.co.kr/html/fund//?o=v&no=1464&l=
# https://www.38.co.kr/html/fund//?o=v&no=1457&l=
# https://www.38.co.kr/html/fund//?o=v&no=1460&l=
# https://www.38.co.kr/html/fund//?o=v&no=1458&l=
# https://www.38.co.kr/html/fund//?o=v&no=1462&l=
# https://www.38.co.kr/html/fund//?o=v&no=1448&l=
# https://www.38.co.kr/html/fund//?o=v&no=1461&l=
# https://www.38.co.kr/html/fund//?o=v&no=1454&l=
# https://www.38.co.kr/html/fund//?o=v&no=1459&l=
# https://www.38.co.kr/html/fund//?o=v&no=1456&l=
# https://www.38.co.kr/html/fund//?o=v&no=1455&l=
# https://www.38.co.kr/html/fund//?o=v&no=1452&l=
# https://www.38.co.kr/html/fund//?o=v&no=1453&l=
# https://www.38.co.kr/html/fund//?o=v&no=1451&l=
# https://www.38.co.kr/html/fund//?o=v&no=1450&l=
# https://www.38.co.kr/html/fund//?o=v&no=1449&l=
# https://www.38.co.kr/html/fund//?o=v&no=1447&l=
# https://www.38.co.kr/html/fund//?o=v&no=1446&l=
# https://www.38.co.kr/html/fund//?o=v&no=1445&l=
# https://www.38.co.kr/html/fund//?o=v&no=1443&l=
# https://www.38.co.kr/html/fund//?o=v&no=1444&l=
# https://www.38.co.kr/html/fund//?o=v&no=1442&l=
# https://www.38.co.kr/html/fund//?o=v&no=1441&l=
# https://www.38.co.kr/html/fund//?o=v&no=1440&l=
# https://www.38.co.kr/html/fund//?o=v&no=1436&l=
# https://www.38.co.kr/html/fund//?o=v&no=1437&l=
# https://www.38.co.kr/html/fund//?o=v&no=1438&l=
# https://www.38.co.kr/html/fund//?o=v&no=1435&l=
# https://www.38.co.kr/html/fund//?o=v&no=1433&l=
# https://www.38.co.kr/html/fund//?o=v&no=1434&l=
# https://www.38.co.kr/html/fund//?o=v&no=1432&l=
# https://www.38.co.kr/html/fund//?o=v&no=1430&l=
# https://www.38.co.kr/html/fund//?o=v&no=1429&l=
# https://www.38.co.kr/html/fund//?o=v&no=1431&l=
# https://www.38.co.kr/html/fund//?o=v&no=1421&l=
# https://www.38.co.kr/html/fund//?o=v&no=1428&l=
# https://www.38.co.kr/html/fund//?o=v&no=1427&l=
# https://www.38.co.kr/html/fund//?o=v&no=1426&l=
# https://www.38.co.kr/html/fund//?o=v&no=1425&l=
# https://www.38.co.kr/html/fund//?o=v&no=1422&l=
# https://www.38.co.kr/html/fund//?o=v&no=1424&l=
# https://www.38.co.kr/html/fund//?o=v&no=1423&l=
# https://www.38.co.kr/html/fund//?o=v&no=1420&l=
# https://www.38.co.kr/html/fund//?o=v&no=1419&l=
# https://www.38.co.kr/html/fund//?o=v&no=1417&l=
# https://www.38.co.kr/html/fund//?o=v&no=1418&l=
# https://www.38.co.kr/html/fund//?o=v&no=1416&l=
# https://www.38.co.kr/html/fund//?o=v&no=1414&l=
# https://www.38.co.kr/html/fund//?o=v&no=1415&l=
# https://www.38.co.kr/html/fund//?o=v&no=1411&l=
# https://www.38.co.kr/html/fund//?o=v&no=1412&l=
# https://www.38.co.kr/html/fund//?o=v&no=1413&l=
# https://www.38.co.kr/html/fund//?o=v&no=1410&l=
# https://www.38.co.kr/html/fund//?o=v&no=1409&l=
# https://www.38.co.kr/html/fund//?o=v&no=1408&l=
# https://www.38.co.kr/html/fund//?o=v&no=1407&l=
# https://www.38.co.kr/html/fund//?o=v&no=1406&l=
# https://www.38.co.kr/html/fund//?o=v&no=1405&l=
# https://www.38.co.kr/html/fund//?o=v&no=1401&l=
# https://www.38.co.kr/html/fund//?o=v&no=1403&l=
# https://www.38.co.kr/html/fund//?o=v&no=1402&l=
# https://www.38.co.kr/html/fund//?o=v&no=1404&l=
# https://www.38.co.kr/html/fund//?o=v&no=1399&l=
# https://www.38.co.kr/html/fund//?o=v&no=1396&l=
# https://www.38.co.kr/html/fund//?o=v&no=1398&l=
# https://www.38.co.kr/html/fund//?o=v&no=1397&l=
# https://www.38.co.kr/html/fund//?o=v&no=1394&l=
# https://www.38.co.kr/html/fund//?o=v&no=1393&l=
# https://www.38.co.kr/html/fund//?o=v&no=1392&l=
# https://www.38.co.kr/html/fund//?o=v&no=1390&l=
# https://www.38.co.kr/html/fund//?o=v&no=1391&l=
# https://www.38.co.kr/html/fund//?o=v&no=1389&l=
# https://www.38.co.kr/html/fund//?o=v&no=1388&l=
# https://www.38.co.kr/html/fund//?o=v&no=1386&l=
# https://www.38.co.kr/html/fund//?o=v&no=1387&l=
# https://www.38.co.kr/html/fund//?o=v&no=1384&l=
# https://www.38.co.kr/html/fund//?o=v&no=1385&l=
# https://www.38.co.kr/html/fund//?o=v&no=1376&l=
# https://www.38.co.kr/html/fund//?o=v&no=1377&l=
# https://www.38.co.kr/html/fund//?o=v&no=1381&l=
# https://www.38.co.kr/html/fund//?o=v&no=1379&l=
# https://www.38.co.kr/html/fund//?o=v&no=1380&l=
# https://www.38.co.kr/html/fund//?o=v&no=1383&l=
# https://www.38.co.kr/html/fund//?o=v&no=1375&l=
# https://www.38.co.kr/html/fund//?o=v&no=1382&l=
# https://www.38.co.kr/html/fund//?o=v&no=1374&l=
# https://www.38.co.kr/html/fund//?o=v&no=1373&l=
# https://www.38.co.kr/html/fund//?o=v&no=1372&l=
# https://www.38.co.kr/html/fund//?o=v&no=1368&l=
# https://www.38.co.kr/html/fund//?o=v&no=1369&l=
# https://www.38.co.kr/html/fund//?o=v&no=1370&l=
# https://www.38.co.kr/html/fund//?o=v&no=1371&l=
# https://www.38.co.kr/html/fund//?o=v&no=1359&l=
# https://www.38.co.kr/html/fund//?o=v&no=1367&l=
# https://www.38.co.kr/html/fund//?o=v&no=1366&l=
# https://www.38.co.kr/html/fund//?o=v&no=1348&l=
# https://www.38.co.kr/html/fund//?o=v&no=1365&l=
# https://www.38.co.kr/html/fund//?o=v&no=1360&l=
# https://www.38.co.kr/html/fund//?o=v&no=1362&l=
# https://www.38.co.kr/html/fund//?o=v&no=1364&l=
# https://www.38.co.kr/html/fund//?o=v&no=1361&l=
# https://www.38.co.kr/html/fund//?o=v&no=1363&l=
# https://www.38.co.kr/html/fund//?o=v&no=1357&l=
# https://www.38.co.kr/html/fund//?o=v&no=1353&l=
# https://www.38.co.kr/html/fund//?o=v&no=1358&l=
# https://www.38.co.kr/html/fund//?o=v&no=1355&l=
# https://www.38.co.kr/html/fund//?o=v&no=1356&l=
# https://www.38.co.kr/html/fund//?o=v&no=1352&l=
# https://www.38.co.kr/html/fund//?o=v&no=1351&l=
# https://www.38.co.kr/html/fund//?o=v&no=1349&l=
# https://www.38.co.kr/html/fund//?o=v&no=1347&l=
# https://www.38.co.kr/html/fund//?o=v&no=1345&l=
# https://www.38.co.kr/html/fund//?o=v&no=1341&l=
# https://www.38.co.kr/html/fund//?o=v&no=1340&l=
# https://www.38.co.kr/html/fund//?o=v&no=1344&l=
# https://www.38.co.kr/html/fund//?o=v&no=1332&l=
# https://www.38.co.kr/html/fund//?o=v&no=1342&l=
# https://www.38.co.kr/html/fund//?o=v&no=1339&l=
# https://www.38.co.kr/html/fund//?o=v&no=1334&l=
# https://www.38.co.kr/html/fund//?o=v&no=1338&l=
# https://www.38.co.kr/html/fund//?o=v&no=1336&l=
# https://www.38.co.kr/html/fund//?o=v&no=1333&l=
# https://www.38.co.kr/html/fund//?o=v&no=1335&l=
# https://www.38.co.kr/html/fund//?o=v&no=1337&l=
# https://www.38.co.kr/html/fund//?o=v&no=1330&l=
# https://www.38.co.kr/html/fund//?o=v&no=1326&l=
# https://www.38.co.kr/html/fund//?o=v&no=1328&l=
# https://www.38.co.kr/html/fund//?o=v&no=1327&l=
# https://www.38.co.kr/html/fund//?o=v&no=1325&l=
# https://www.38.co.kr/html/fund//?o=v&no=1322&l=
# https://www.38.co.kr/html/fund//?o=v&no=1323&l=
# https://www.38.co.kr/html/fund//?o=v&no=1321&l=
# https://www.38.co.kr/html/fund//?o=v&no=1320&l=
# https://www.38.co.kr/html/fund//?o=v&no=1319&l=
# https://www.38.co.kr/html/fund//?o=v&no=1324&l=
# https://www.38.co.kr/html/fund//?o=v&no=1317&l=
# https://www.38.co.kr/html/fund//?o=v&no=1315&l=
# https://www.38.co.kr/html/fund//?o=v&no=1318&l=
# https://www.38.co.kr/html/fund//?o=v&no=1316&l=
# https://www.38.co.kr/html/fund//?o=v&no=1314&l=
# https://www.38.co.kr/html/fund//?o=v&no=1312&l=
# https://www.38.co.kr/html/fund//?o=v&no=1311&l=
# https://www.38.co.kr/html/fund//?o=v&no=1313&l=
# https://www.38.co.kr/html/fund//?o=v&no=1310&l=
# https://www.38.co.kr/html/fund//?o=v&no=1307&l=
# https://www.38.co.kr/html/fund//?o=v&no=1308&l=
# https://www.38.co.kr/html/fund//?o=v&no=1309&l=
# https://www.38.co.kr/html/fund//?o=v&no=1305&l=
# https://www.38.co.kr/html/fund//?o=v&no=1303&l=
# https://www.38.co.kr/html/fund//?o=v&no=1304&l=
# https://www.38.co.kr/html/fund//?o=v&no=1301&l=
# https://www.38.co.kr/html/fund//?o=v&no=1302&l=
# https://www.38.co.kr/html/fund//?o=v&no=1300&l=
# https://www.38.co.kr/html/fund//?o=v&no=1298&l=
# https://www.38.co.kr/html/fund//?o=v&no=1297&l=
# https://www.38.co.kr/html/fund//?o=v&no=1294&l=
# https://www.38.co.kr/html/fund//?o=v&no=1295&l=
# https://www.38.co.kr/html/fund//?o=v&no=1293&l=
# https://www.38.co.kr/html/fund//?o=v&no=1292&l=
# https://www.38.co.kr/html/fund//?o=v&no=1291&l=
# https://www.38.co.kr/html/fund//?o=v&no=1290&l=
# https://www.38.co.kr/html/fund//?o=v&no=1287&l=
# https://www.38.co.kr/html/fund//?o=v&no=1289&l=
# https://www.38.co.kr/html/fund//?o=v&no=1286&l=
# https://www.38.co.kr/html/fund//?o=v&no=1284&l=
# https://www.38.co.kr/html/fund//?o=v&no=1285&l=
# https://www.38.co.kr/html/fund//?o=v&no=1281&l=
# https://www.38.co.kr/html/fund//?o=v&no=1283&l=
# https://www.38.co.kr/html/fund//?o=v&no=1277&l=
# https://www.38.co.kr/html/fund//?o=v&no=1280&l=
# https://www.38.co.kr/html/fund//?o=v&no=1278&l=
# https://www.38.co.kr/html/fund//?o=v&no=1276&l=
# https://www.38.co.kr/html/fund//?o=v&no=1275&l=
# https://www.38.co.kr/html/fund//?o=v&no=1274&l=
# https://www.38.co.kr/html/fund//?o=v&no=1273&l=
# https://www.38.co.kr/html/fund//?o=v&no=1269&l=
# https://www.38.co.kr/html/fund//?o=v&no=1272&l=
# https://www.38.co.kr/html/fund//?o=v&no=1271&l=
# https://www.38.co.kr/html/fund//?o=v&no=1267&l=
# https://www.38.co.kr/html/fund//?o=v&no=1270&l=
# https://www.38.co.kr/html/fund//?o=v&no=1268&l=
# https://www.38.co.kr/html/fund//?o=v&no=1264&l=
# https://www.38.co.kr/html/fund//?o=v&no=1266&l=
# https://www.38.co.kr/html/fund//?o=v&no=1265&l=
# https://www.38.co.kr/html/fund//?o=v&no=1262&l=
# https://www.38.co.kr/html/fund//?o=v&no=1263&l=
# https://www.38.co.kr/html/fund//?o=v&no=1261&l=
# https://www.38.co.kr/html/fund//?o=v&no=1260&l=
# https://www.38.co.kr/html/fund//?o=v&no=1258&l=
# https://www.38.co.kr/html/fund//?o=v&no=1256&l=
# https://www.38.co.kr/html/fund//?o=v&no=1257&l=
# https://www.38.co.kr/html/fund//?o=v&no=1254&l=
# https://www.38.co.kr/html/fund//?o=v&no=1255&l=
# https://www.38.co.kr/html/fund//?o=v&no=1253&l=
# https://www.38.co.kr/html/fund//?o=v&no=1251&l=
# https://www.38.co.kr/html/fund//?o=v&no=1252&l=
# https://www.38.co.kr/html/fund//?o=v&no=1250&l=
# https://www.38.co.kr/html/fund//?o=v&no=1248&l=
# https://www.38.co.kr/html/fund//?o=v&no=1249&l=
# https://www.38.co.kr/html/fund//?o=v&no=1246&l=
# https://www.38.co.kr/html/fund//?o=v&no=1247&l=
# https://www.38.co.kr/html/fund//?o=v&no=1245&l=
# https://www.38.co.kr/html/fund//?o=v&no=1244&l=
# https://www.38.co.kr/html/fund//?o=v&no=1242&l=
# https://www.38.co.kr/html/fund//?o=v&no=1243&l=
# https://www.38.co.kr/html/fund//?o=v&no=1241&l=
# https://www.38.co.kr/html/fund//?o=v&no=1239&l=
# https://www.38.co.kr/html/fund//?o=v&no=1240&l=
# https://www.38.co.kr/html/fund//?o=v&no=1238&l=
# https://www.38.co.kr/html/fund//?o=v&no=1229&l=
# https://www.38.co.kr/html/fund//?o=v&no=1237&l=
# https://www.38.co.kr/html/fund//?o=v&no=1236&l=
# https://www.38.co.kr/html/fund//?o=v&no=1234&l=
# https://www.38.co.kr/html/fund//?o=v&no=1233&l=
# https://www.38.co.kr/html/fund//?o=v&no=1235&l=
# https://www.38.co.kr/html/fund//?o=v&no=1227&l=
# https://www.38.co.kr/html/fund//?o=v&no=1230&l=
# https://www.38.co.kr/html/fund//?o=v&no=1231&l=
# https://www.38.co.kr/html/fund//?o=v&no=1228&l=
# https://www.38.co.kr/html/fund//?o=v&no=1226&l=
# https://www.38.co.kr/html/fund//?o=v&no=1225&l=
# https://www.38.co.kr/html/fund//?o=v&no=1223&l=
# https://www.38.co.kr/html/fund//?o=v&no=1224&l=
# https://www.38.co.kr/html/fund//?o=v&no=1222&l=
# https://www.38.co.kr/html/fund//?o=v&no=1220&l=
# https://www.38.co.kr/html/fund//?o=v&no=1221&l=
# https://www.38.co.kr/html/fund//?o=v&no=1219&l=
# https://www.38.co.kr/html/fund//?o=v&no=1216&l=
# https://www.38.co.kr/html/fund//?o=v&no=1218&l=
# https://www.38.co.kr/html/fund//?o=v&no=1217&l=
# https://www.38.co.kr/html/fund//?o=v&no=1210&l=
# https://www.38.co.kr/html/fund//?o=v&no=1214&l=
# https://www.38.co.kr/html/fund//?o=v&no=1209&l=
# https://www.38.co.kr/html/fund//?o=v&no=1215&l=
# https://www.38.co.kr/html/fund//?o=v&no=1212&l=
# https://www.38.co.kr/html/fund//?o=v&no=1211&l=
# https://www.38.co.kr/html/fund//?o=v&no=1213&l=
# https://www.38.co.kr/html/fund//?o=v&no=1208&l=
# https://www.38.co.kr/html/fund//?o=v&no=1202&l=
# https://www.38.co.kr/html/fund//?o=v&no=1207&l=
# https://www.38.co.kr/html/fund//?o=v&no=1206&l=
# https://www.38.co.kr/html/fund//?o=v&no=1194&l=
# https://www.38.co.kr/html/fund//?o=v&no=1204&l=
# https://www.38.co.kr/html/fund//?o=v&no=1203&l=
# https://www.38.co.kr/html/fund//?o=v&no=1196&l=
# https://www.38.co.kr/html/fund//?o=v&no=1199&l=
# https://www.38.co.kr/html/fund//?o=v&no=1198&l=
# https://www.38.co.kr/html/fund//?o=v&no=1201&l=
# https://www.38.co.kr/html/fund//?o=v&no=1195&l=
# https://www.38.co.kr/html/fund//?o=v&no=1200&l=
# https://www.38.co.kr/html/fund//?o=v&no=1192&l=
# https://www.38.co.kr/html/fund//?o=v&no=1191&l=
# https://www.38.co.kr/html/fund//?o=v&no=1183&l=
# https://www.38.co.kr/html/fund//?o=v&no=1189&l=
# https://www.38.co.kr/html/fund//?o=v&no=1184&l=
# https://www.38.co.kr/html/fund//?o=v&no=1180&l=

# %%
t3 = "  신주모집 : 4,500,000 주 (96.77%) 
	/   구주매출 : 150,000 주 (3.23%)    """

# %%
test_url = "https://www.38.co.kr/html/fund/?o=v&no=1737&l=" ##lg엔솔
test2 = "https://www.38.co.kr/html/fund//?o=v&no=1799&l="
print(get_ipo_data(test2))
# Out:
# OrderedDict([('ipo_total', '1180000'), ('face_value', '500'), ('new_rate', '12.29%'), ('ipo_type', '\xa0 신주모집 : 1,035,000 주 (87.71%)\xa0\n\t/ \xa0 구주매출 : 145,000 주 (12.29%)    '), ('wish_price_min', '34000'), ('wish_price_max', '44000'), ('sub_rate', '\xa0  '), ('final_price', ''), ('host_party', '\xa0 삼성증권\n'), ('employee_rate', '\xa0  주 \xa0      \xa0 '), ('employee_margin', '\xa0100% '), ('org_rate', '\xa0 826,000~885,000 주 \xa0(70~75%)      \xa0 '), ('normal_rate', '\xa0 295,000~354,000 주 \xa0(25~30%)      \xa0 '), ('normal_margin', '\xa050% '), ('15일 확약', None), ('1개월 확약', None), ('3개월 확약', None), ('6개월 확약', None), ('총 수량 대비 비율(%)', None), ('demand_count', ''), ('demand_ratio', '')])

# %%
def clean_dict(input_dict):  ## my_dict is a list of dict
    ini_list= [
    '15일 확약',
    '1개월 확약',
    '3개월 확약',
    '6개월 확약',
    '총 수량 대비 비율(%)',
    ]
    template_dict = OrderedDict(zip(ini_list, [None]*len(ini_list)))
    
    for key, value in input_dict.items():
        template_dict[key] = value
    return template_dict

t_dict = {'15일 확약':'12312321'}
print(clean_dict(t_dict))
# Out:
# OrderedDict([('15일 확약', '12312321'), ('1개월 확약', None), ('3개월 확약', None), ('6개월 확약', None), ('총 수량 대비 비율(%)', None)])

# %%
t2 = """
총공모주식수 
  42,500,000 주
 액면가 
  500 원


상장공모
  신주모집 : 34,000,000 주 (80%) 
	/   구주매출 : 8,500,000 주 (20%)    


희망공모가액
   257,000 ~ 300,000 원
 청약경쟁률 
"""

print("청약경쟁률" in t2)
# Out:
# True

# %%
import re
t = ' \xa0 257,000 ~ 300,000 원'
wish_price_min = re.sub('[^0-9]','', t.split(" ~ ")[0])
wish_price_max = re.sub('[^0-9]','', t.split(" ~ ")[1])
print(wish_price_max, wish_price_min)
# Out:
# 300000 257000
